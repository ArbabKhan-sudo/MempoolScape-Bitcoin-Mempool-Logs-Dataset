# %% [markdown]
# <a href="https://colab.research.google.com/github/ArbabKhan-sudo/MempoolScape-Bitcoin-Mempool-Logs-Dataset/blob/main/BTC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import files
uploaded = files.upload()

# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-9728be7f-6117-45c5-95b3-20984e502492" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9728be7f-6117-45c5-95b3-20984e502492">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets download -d itshaseebsaeed/bitcoin-mempool-state-data
# Out:
# ...
# 100% 998M/0.98G [01:00<00:00, 20.8MB/s]
# 100% 0.98G/0.98G [01:00<00:00, 17.4MB/s]

# %%
# !ls
# Out:
#  bitcoin-mempool-state-data.zip  'kaggle (1).json'   sample_data

# %%
# !unzip bitcoin-mempool-state-data.zip
# Out:
# Archive:  bitcoin-mempool-state-data.zip
#   inflating: processed_final_2.csv

# %%
# !ls
# Out:
# bitcoin-mempool-state-data.zip	processed_final_2.csv  sample_data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
#,nrows=15000000
# check complete
# Data set visualiations

filename = "processed_final_2.csv"

batch_size = 10000

for train in pd.read_csv(filename, chunksize=batch_size):
    print(train.shape)
# Out:
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# (10000, 19)
# ...

# %%
# Assuming "Unamed:0" is the index column
data.set_index('Success', inplace=True)

# Find the missing and continuous ranges
missing_ranges = []
continuous_ranges = []
start_range = None

for i in range(data.index.min(), data.index.max() + 1):
    if i not in data.index:
        if start_range is not None:
            continuous_ranges.append((start_range, i - 1))
            start_range = None
        missing_ranges.append(i)
    elif start_range is None:
        start_range = i

if start_range is not None:
    continuous_ranges.append((start_range, data.index.max()))

print("Missing Ranges:", missing_ranges)
print("Continuous Ranges:", continuous_ranges)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-634a33894bc7> in <cell line: 7>()
#       5
#       6 # Assuming "Unamed:0" is the index column
# ----> 7 data.set_index('Success', inplace=True)
#       8
#       9 # Find the missing and continuous ranges
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# ...

# %%
train.head()
# Out:
#            Success  DescendantCount  DescendantFee  DescendantSize  \
# 26030000  26090821                1         105057            1881
# 26030001  26090822                1          11200             449
# 26030002  26090823                1         104267            1732
# 26030003  26090824                1         101346            1142
# 26030004  26090817                0              0               0
#
#           EntryBlock    ExitTime   EntryTime  TxSize  TxFee   TxFeePkb  TxIn  \
# 26030000      672229  1614307774  1614303057     964   7628   7.912863     6
# 26030001      672236  1614307774  1614306308     224   5575  24.888393     1
# 26030002      672229  1614307774  1614303063     815   6838   8.390184     5
# 26030003      672229  1614307774  1614303069     225   3917  17.408889     1
# 26030004      672236  1614307774  1614306305     372   9250  24.865591     2
#
#           TxOut  ExitBlock  BlocksToConfirm       PPF  SecSinceLB   Offset  \
# ...

# %%
train
# Out:
#           Unnamed: 0  DescendantCount  DescendantFee  DescendantSize  \
# 26030000    26090821                1         105057            1881
# 26030001    26090822                1          11200             449
# 26030002    26090823                1         104267            1732
# 26030003    26090824                1         101346            1142
# 26030004    26090817                0              0               0
# ...              ...              ...            ...             ...
# 26031683    26090271                1          10975             450
# 26031684    26090272                0              0             142
# 26031685    26090273                1          20574             891
# 26031686    26090267                0              0               0
# 26031687    26091757                0              0               0
#
#           EntryBlock    ExitTime   EntryTime  TxSize  TxFee   TxFeePkb  TxIn  \
# ...

# %%
train.dtypes
# Out:
# Unnamed: 0            int64
# DescendantCount       int64
# DescendantFee         int64
# DescendantSize        int64
# EntryBlock            int64
# ExitTime              int64
# EntryTime             int64
# TxSize                int64
# TxFee                 int64
# TxFeePkb            float64
# TxIn                  int64
# TxOut                 int64
# ExitBlock             int64
# BlocksToConfirm       int64
# PPF                 float64
# SecSinceLB          float64
# Offset                int64
# CountOnEntryTime    float64
# BtcPrice            float64
# dtype: object

# %%
train['DescendantCount'] = pd.to_numeric(train['DescendantCount'], errors='coerce')
train['DescendantFee'] = pd.to_numeric(train['DescendantFee'], errors='coerce')
train['DescendantSize'] = pd.to_numeric(train['DescendantSize'], errors='coerce')
train['EntryBlock'] = pd.to_numeric(train['EntryBlock'], errors='coerce')
train['ExitTime'] = pd.to_numeric(train['ExitTime'], errors='coerce')
train['EntryTime'] = pd.to_numeric(train['EntryTime'], errors='coerce')
train['TxSize'] = pd.to_numeric(train['TxSize'], errors='coerce')
train['TxFee'] = pd.to_numeric(train['TxFee'], errors='coerce')
train['TxFeePkb'] = pd.to_numeric(train['TxFeePkb'], errors='coerce')
train['TxIn'] = pd.to_numeric(train['TxIn'], errors='coerce')
train['TxOut'] = pd.to_numeric(train['TxOut'], errors='coerce')
train['ExitBlock'] = pd.to_numeric(train['ExitBlock'], errors='coerce')
train['BlocksToConfirm'] = pd.to_numeric(train['BlocksToConfirm'], errors='coerce')
train['PPF'] = pd.to_numeric(train['PPF'], errors='coerce')
train['SecSinceLB'] = pd.to_numeric(train['SecSinceLB'], errors='coerce')
train['Offset'] = pd.to_numeric(train['Offset'], errors='coerce')
train['CountOnEntryTime'] = pd.to_numeric(train['CountOnEntryTime'], errors='coerce')
train['BtcPrice'] = pd.to_numeric(train['BtcPrice'], errors='coerce')

# %%
train.dtypes
# Out:
# Unnamed: 0            int64
# DescendantCount       int64
# DescendantFee         int64
# DescendantSize        int64
# EntryBlock            int64
# ExitTime              int64
# EntryTime             int64
# TxSize                int64
# TxFee                 int64
# TxFeePkb            float64
# TxIn                  int64
# TxOut                 int64
# ExitBlock             int64
# BlocksToConfirm       int64
# PPF                 float64
# SecSinceLB          float64
# Offset                int64
# CountOnEntryTime    float64
# BtcPrice            float64
# dtype: object

# %%
train.rename(columns={"Unnamed: 0": "Success"}, inplace=True)

train.head()
# Out:
#            Success  DescendantCount  DescendantFee  DescendantSize  \
# 26030000  26090821                1         105057            1881
# 26030001  26090822                1          11200             449
# 26030002  26090823                1         104267            1732
# 26030003  26090824                1         101346            1142
# 26030004  26090817                0              0               0
#
#           EntryBlock    ExitTime   EntryTime  TxSize  TxFee   TxFeePkb  TxIn  \
# 26030000      672229  1614307774  1614303057     964   7628   7.912863     6
# 26030001      672236  1614307774  1614306308     224   5575  24.888393     1
# 26030002      672229  1614307774  1614303063     815   6838   8.390184     5
# 26030003      672229  1614307774  1614303069     225   3917  17.408889     1
# 26030004      672236  1614307774  1614306305     372   9250  24.865591     2
#
#           TxOut  ExitBlock  BlocksToConfirm       PPF  SecSinceLB   Offset  \
# ...

# %%
#.train.fillna

# %%
#train[].sort_values
#train.sort_values(by=['Unnamed: 0'])

# %%
#train = train.reset_index

# %%
train.tail()
# Out:
#            Success  DescendantCount  DescendantFee  DescendantSize  \
# 26031683  26090271                1          10975             450
# 26031684  26090272                0              0             142
# 26031685  26090273                1          20574             891
# 26031686  26090267                0              0               0
# 26031687  26091757                0              0               0
#
#           EntryBlock    ExitTime   EntryTime  TxSize  TxFee   TxFeePkb  TxIn  \
# 26031683      672223  1614307774  1614297556     224   5575  24.888393     1
# 26031684      672218  1614307774  1614296524     223   4260  19.103139     1
# 26031685      672220  1614307774  1614296796     373   9024  24.193029     2
# 26031686      672224  1614307774  1614297769     224   5575  24.888393     1
# 26031687      672238  1614307774  1614307726     191   4825  25.261780     1
#
#           TxOut  ExitBlock  BlocksToConfirm       PPF  SecSinceLB   Offset  \
# ...

# %%
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
#MinMaxScalar is used to normalize the value

# %%
cov_matrix = np.cov(train.T)

# %%
train
# Out:
#            Success  DescendantCount  DescendantFee  DescendantSize  \
# 26030000  26090821                1         105057            1881
# 26030001  26090822                1          11200             449
# 26030002  26090823                1         104267            1732
# 26030003  26090824                1         101346            1142
# 26030004  26090817                0              0               0
# ...            ...              ...            ...             ...
# 26031683  26090271                1          10975             450
# 26031684  26090272                0              0             142
# 26031685  26090273                1          20574             891
# 26031686  26090267                0              0               0
# 26031687  26091757                0              0               0
#
#           EntryBlock    ExitTime   EntryTime  TxSize  TxFee   TxFeePkb  TxIn  \
# 26030000      672229  1614307774  1614303057     964   7628   7.912863     6
# ...

# %%
#train.head()

# %%
temp_cov = pd.DataFrame(cov_matrix, columns=train.columns , index=train.columns)
temp_cov
# Out:
#                        Success  DescendantCount  DescendantFee  \
# Success           5.059594e+05        27.188365   7.974064e+05
# DescendantCount   2.718837e+01         0.770464   1.291974e+04
# DescendantFee     7.974064e+05     12919.738277   8.182569e+08
# DescendantSize    4.372200e+04       312.563641   1.553183e+07
# EntryBlock        4.643092e+02        -6.414924  -7.990818e+04
# ExitTime          0.000000e+00         0.000000   0.000000e+00
# EntryTime         1.492568e+05     -3919.711139  -5.022833e+07
# TxSize            5.885247e+04       -19.137126   1.974151e+06
# TxFee            -1.066438e+06      -682.490073   1.620196e+08
# TxFeePkb         -7.202000e+03        -2.375739   2.062763e+04
# TxIn              2.943306e+02        -0.264804  -2.788731e+03
# TxOut             1.442864e+02         0.697697   7.394767e+04
# ExitBlock         0.000000e+00         0.000000   0.000000e+00
# BlocksToConfirm  -4.643092e+02         6.414924   7.990818e+04
# ...

# %%
train.columns
# Out:
# Index(['Success', 'DescendantCount', 'DescendantFee', 'DescendantSize',
#        'EntryBlock', 'ExitTime', 'EntryTime', 'TxSize', 'TxFee', 'TxFeePkb',
#        'TxIn', 'TxOut', 'ExitBlock', 'BlocksToConfirm', 'PPF', 'SecSinceLB',
#        'Offset', 'CountOnEntryTime', 'BtcPrice'],
#       dtype='object')

# %%
scaler = MinMaxScaler(feature_range=(-1 , 1))
cov_matrix = scaler.fit_transform(cov_matrix)

# %%
# Plot the covariance matrixa
num_features = 18

# Plot the covariance matrix
fig = plt.figure(figsize =(20, 12))
sns.heatmap(cov_matrix, annot=True, fmt=".2f")
plt.title('Covariance Matrix')
plt.xlabel('Features')
plt.ylabel('Features')

# Set the tick labels for x-axis and y-axis
plt.xticks(range(num_features))
plt.yticks(range(num_features))

plt.show()
